# %% [markdown]
# ## Introduction
#
# All data problems begin with a question and end with a narrative construct that provides a clear answer. From there, the next step is getting your data. As a Data Scientist, you'll spend an incredible amount of time and skills on acquiring, prepping, cleaning, and normalizing your data. In this tutorial, we'll review some of the best tools used in the rhelm of data acquisition.
#
# But first, let's go into the differences between Data Acquisition, Preparation, and Cleaning.
#
# ### Data Acquisition
#
# Data Acquisition is the process of getting your data, hence the term <i>acquisition</i>. Data doesn't come out of nowhere, so the very first step of any data science problem is going to be getting the data in the first place.
#
# ### Data Preparation
#
# Once you have the data, it might not be in the best format to work with. You might have scraped a bunch of data from a website, but need it in the form of a dataframe to work with it in an easier manner. This process is called data preparation - preparing your data in a format that's easiest to form with.
#
# ### Data Cleaning
#
# Once your data is being stored or handled in a proper manner, that might still not be enough. You might have missing values or values that need normalizing. These inconsistencies that you fix before analysis refers to data cleaning.

# %% [markdown]
# ## Reading, Writing, and Handling Data Files
#
# The simplest way of acquiring data is downloading a file - either from a website, straight from your desktop, or elsewhere. Once the data is downloaded, you'll open the files for reading and possible writing.
#
# ### CSV files
#
# Very often, you'll have to work with CSV files. A csv file is a comma-separated values file stores tabular data in plain text.
#
# In the following examples, we'll be working with NBA data, which you can download from [here](https://github.com/ByteAcademyCo/data-acq/blob/master/nba.csv).
#
# #### CSV
#
# Python has a csv module, which you can utilize to work with CSV files.

# %%
import csv

# %% [markdown]
# Then, with the following 4 lines, you can print each row

# %%
with open('nba.csv', 'rt') as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['player', 'pos', 'age', 'bref_team_id', 'g', 'gs', 'mp', 'fg', 'fga', 'fg.', 'x3p', 'x3pa', 'x3p.', 'x2p', 'x2pa', 'x2p.', 'efg.', 'ft', 'fta', 'ft.', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf', 'pts', 'season', 'season_end']
# ['Quincy Acy', 'SF', '23', 'TOT', '63', '0', '847', '66', '141', '0.468', '4', '15', '0.266666666666667', '62', '126', '0.492063492063492', '0.482', '35', '53', '0.66', '72', '144', '216', '28', '23', '26', '30', '122', '171', '2013-2014', '2013']
# ['Steven Adams', 'C', '20', 'OKC', '81', '20', '1197', '93', '185', '0.503', '0', '0', 'NA', '93', '185', '0.502702702702703', '0.503', '79', '136', '0.581', '142', '190', '332', '43', '40', '57', '71', '203', '265', '2013-2014', '2013']
# ['Jeff Adrien', 'PF', '27', 'TOT', '53', '12', '961', '143', '275', '0.52', '0', '0', 'NA', '143', '275', '0.52', '0.52', '76', '119', '0.639', '102', '204', '306', '38', '24', '36', '39', '108', '362', '2013-2014', '2013']
# ['Arron Afflalo', 'SG', '28', 'ORL', '73', '73', '2552', '464', '1011', '0.459', '128', '300', '0.426666666666667', '336', '711', '0.472573839662447', '0.522', '274', '336', '0.815', '32', '230', '262', '248', '35', '3', '146', '136', '1330', '2013-2014', '2013']
# ['Alexis Ajinca', 'C', '25', 'NOP', '56', '30', '951', '136', '249', '0.546', '0', '1', '0', '136', '248', '0.548387096774194', '0.546', '56', '67', '0.836', '94', '183', '277', '40', '23', '46', '63', '187', '328', '2013-2014', '2013']
# ['Tony Wroten', 'SG', '20', 'PHI', '72', '16', '1765', '345', '808', '0.427', '40', '188', '0.212765957446809', '305', '620', '0.491935483870968', '0.452', '209', '326', '0.641', '69', '159', '228', '217', '78', '16', '204', '151', '939', '2013-2014', '2013']
# ['Nick Young', 'SG', '28', 'LAL', '64', '9', '1810', '387', '889', '0.435', '135', '350', '0.385714285714286', '252', '539', '0.467532467532468', '0.511', '235', '285', '0.825', '29', '137', '166', '95', '46', '12', '95', '156', '1144', '2013-2014', '2013']
# ['Thaddeus Young', 'PF', '25', 'PHI', '79', '78', '2718', '582', '1283', '0.454', '90', '292', '0.308219178082192', '492', '991', '0.496468213925328', '0.489', '163', '229', '0.712', '166', '310', '476', '182', '167', '36', '165', '213', '1417', '2013-2014', '2013']
# ['Cody Zeller', 'C', '21', 'CHA', '82', '3', '1416', '172', '404', '0.426', '0', '1', '0', '172', '403', '0.426799007444169', '0.426', '146', '200', '0.73', '118', '235', '353', '92', '40', '41', '87', '170', '490', '2013-2014', '2013']
# ['Tyler Zeller', 'C', '24', 'CLE', '70', '9', '1049', '156', '290', '0.538', '0', '1', '0', '156', '289', '0.539792387543253', '0.538', '87', '121', '0.719', '103', '179', '282', '36', '18', '38', '60', '137', '399', '2013-2014', '2013']

# %% [markdown]
# Fairly straightforward, but let's see how else we can accomplish this.

# %% [markdown]
# #### Pandas
#
# Alternatively, you can use Pandas. Pandas is great for working with CSV files because it handles DataFrames.
#
# We begin by importing the needed libraries: pandas.

# %%
import pandas as pd

# %% [markdown]
# Then we use pandas to read the CSV file and show the first few rows.

# %%
task_data = pd.read_csv("nba.csv")
task_data.head()
# Out:
#           player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 0     Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468
# 1   Steven Adams   C   20          OKC  81  20  1197   93   185  0.503
# 2    Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520
# 3  Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459
# 4  Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546
#
#       ...      drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# 0     ...      144  216   28   23   26   30  122   171  2013-2014        2013
# 1     ...      190  332   43   40   57   71  203   265  2013-2014        2013
# 2     ...      204  306   38   24   36   39  108   362  2013-2014        2013
# 3     ...      230  262  248   35    3  146  136  1330  2013-2014        2013
# 4     ...      183  277   40   23   46   63  187   328  2013-2014        2013
#
# [5 rows x 31 columns]

# %% [markdown]
# As you can see, by using pandas, we're able to fasten the process of viewing our data, as well as view it in a much more readable format.

# %% [markdown]
# #### R Programming
#
# We've just gone through how to read CSV files in Python. But how do you do this in R? Pretty simply, actually. R has built in functions to handle CSV files, so you don't even have to use a library to accomplish what we just did with Python.

# %%
data <- read.csv("nba.csv")

# %% [markdown]
# ### JSON
#
# Because HTTP is a protocol for transferring text, the data you request through a web API (which we'll go through soon enough) needs to be serialized into a string format, usually in JavaScript Object Notation (JSON). JavaScript objects look quite similar to Python dicts, which makes their string representations easy to interpret:
#
# ```
# {
#  "name" : "Lesley Cordero",
#  "job" : "Data Scientist",
#  "topics" : [ "data", "science", "data science"]
# }
# ```
#
# Python has a module sepcifically for working with JSON, called `json`, which we can use as follows:

# %%
import json
serialized = """ { 
 "name" : "Lesley Cordero",
 "job" : "Data Scientist",
 "topics" : [ "data", "science", "data science"] 
} """

# %% [markdown]
# Next, we parse the JSON to create a Python dict, using the json module:

# %%
deserialized = json.loads(serialized)
print(deserialized)
# Out:
# {'name': 'Lesley Cordero', 'job': 'Data Scientist', 'topics': ['data', 'science', 'data science']}

# %% [markdown]
# #### jsonlite
#
# Now, in R, working with JSON can be a bit more complicated. Unlike Python, R doesn't have a data type that resembles JSON closely (dictionaries in Python). So we have to work with what we do have, which is lists, vectors, and matrices.
#
# Working with the same data from the Python example, we have:

# %%
serialized = '{ 
 "name" : "Lesley Cordero",
 "job" : "Data Scientist",
 "topics" : [ "data", "science", "data science"] 
} '

# %% [markdown]
# Now, if we want to properly load this into R, we'll be using the `jsonlite` library.

# %%
library("jsonlite")

# %% [markdown]
# Once we've loaded the library, we'll use the `fromJSON` function to convert this into a data type R is more familiar with: <b>lists</b>.

# %%
l <- fromJSON(serialized, simplifyVector=TRUE)

# %% [markdown]
# Notice that `simplifyVector` is set to `TRUE`. When simplifyMatrix is enabled, JSON arrays containing equal-length sub-arrays simplify into a matrix.
#
# And to convert this back to JSON, we type:

# %%
toJSON(l, pretty=TRUE)
# Out:
# {
#   "name": ["Lesley Cordero"],
#   "job": ["Data Scientist"],
#   "topics": ["data", "science", "data science"]
# }

# %% [markdown]
# ## APIs
#
# There are several ways to extract information from the web. Use of APIs, Application Program Interfaces, is probably the best way to extract data from a website. APIs are especially great if your data is constantly changing. Many websites have public APIs providing data feeds via JSON or some other format.
#
# There are a number of ways to access these APIs from Python. In order to get the data, we make a request to a webserver, hence an easy way is to use the `requests` package.
#
# ### GET request
#
# There are many different types of requests. The most simplest is a GET request. GET requests are used to retrieve your data. In Python, you can make a get request to get the latest position of the international space station from the `OpenNotify` API.

# %%
import requests
response = requests.get("http://api.open-notify.org/iss-now.json")
print(response.status_code)
# Out:
# 200

# %% [markdown]
# Which brings us to status codes.

# %% [markdown]
# ### Status Codes
#
# What we just printed was a status code of `200`. Status codes are returned with every request made to a web server and indicate what happened with a request. The following are the most common types of status codes:
#
# - `200` - everything worked as planned!
# - `301` - the server is redirecting you to anotehr endpoint (domain).
# - `400` - it means you made a bad request by not sending the right data or some other error.
# - `401` - you're not authenticated, which means you don't have access to the server.
# - `403` - this means access is forbidden.
# - `404` - whatever you tried to access wasn't found.
#
# Notice that if we try to access something that doesn't exist, we'll get a `404` error:

# %%
response = requests.get("http://api.open-notify.org/iss-pass")
print(response.status_code)
# Out:
# 404

# %% [markdown]
# Let's try a get request where the status code returned is `404`.

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json")
print(response.status_code)
# Out:
# 400

# %% [markdown]
# Like we mentioned before, this indicated a bad request. This is because it requires two parameters, as you can see [here](http://open-notify.org/Open-Notify-API/ISS-Pass-Times/).
#
# We set these with an optional `params` variable. You can opt to make a dictionary and then pass it into the `requests.get` function, like follows:

# %%
parameters = {"lat": 40.71, "lon": -74}
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)

# %% [markdown]
# You can skip the variable portion with the following instead:

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74")
print(response.content)
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1496864501, \n    "latitude": 40.71, \n    "longitude": -74.0, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 645, \n      "risetime": 1496866724\n    }, \n    {\n      "duration": 591, \n      "risetime": 1496872564\n    }, \n    {\n      "duration": 550, \n      "risetime": 1496878434\n    }, \n    {\n      "duration": 609, \n      "risetime": 1496884248\n    }, \n    {\n      "duration": 638, \n      "risetime": 1496890035\n    }\n  ]\n}\n'

# %% [markdown]
# This is pretty messy, but luckily, we can clean this up into JSON with:

# %%
data = response.json()
print(data)
# Out:
# {'message': 'success', 'request': {'altitude': 100, 'datetime': 1496864501, 'latitude': 40.71, 'longitude': -74.0, 'passes': 5}, 'response': [{'duration': 645, 'risetime': 1496866724}, {'duration': 591, 'risetime': 1496872564}, {'duration': 550, 'risetime': 1496878434}, {'duration': 609, 'risetime': 1496884248}, {'duration': 638, 'risetime': 1496890035}]}

# %% [markdown]
# ### APIs with R
#
# So far we've seen APIs with Python. Let's take a look on how you can use R to do some simple API calls. We'll be working with the `httr` library and the EPDB API, which we load in the next three lines:

# %%
library("httr")
url  <- "http://api.epdb.eu"
path <- "eurlex/directory_code"

# %% [markdown]
# With `httr`, you can make GET requests, like this:

# %%
raw.result <- GET(url=url, path=path)
print(raw.result)
# Out:
# Response [http://api.epdb.eu/eurlex/directory_code/]
#   Date: 2017-06-07 19:44
#   Status: 200
#   Content-Type: application/json
#   Size: 121 kB

# %% [markdown]
# Now let's pull the name entities from this GET request:

# %%
print(names(raw.result))
# Out:
#  [1] "url"         "status_code" "headers"     "all_headers" "cookies"
#  [6] "content"     "date"        "times"       "request"     "handle"

# %% [markdown]
# You can extract each of the entitites above with the `$` character, like this:

# %%
raw.result$status_code
# Out:
# [1] 200

# %% [markdown]
# ## Web Scraping
#
# Web Scraping tools are specifically developed for extracting information from websites. Web Scraping mostly focuses on the transformation of unstructured data (HTML format) on the web into structured data (database or spreadsheet).
#
# ### HTML
#
# While performing web scraping, we deal with html tags. Thus, we must have good understanding of them. Below is the basic syntax of HTML:
#
# ``` html
# <!DOCTYPE html>
# <html>
# 	<body>
# 		<h1> First Heading </h1>
# 		<p> First Paragraph </p>
# 	</body>
# </html>
# ```
# Let's break down each of these tags:
#
# 1. `<!DOCTYPE html>`: This is the initial HTML declaration.
# 2. `<html>`: The HTML document is going to be contained within this tag.
# 3. `<body>`: This is where the visible portion of the HTML document is between.
# 4. `<h1>`: This is an HTML heading.
# 5. `<p>`: HTML paragraphs are defined here.
#
# We've also got the following tags:
#
# - `<a>`: These always define HTML links, such as with
# ``` HTML
# <a href="http://byteacademy.co">This is Byte Academy's website!</a>
# ```
# - `<table>`: HTML tables are defined with this tag, such as:
# *Note that the `<tr>`are rows and `<td>` defines columns.
# ``` HTML
# <table style="width:100%">
# 	<tr>
# 		<td>Lesley</td>
# 		<td>Cordero</td>
# 		<td>24</td>
# 	</tr>
# 	<tr>
# 		<td>Helen</td>
# 		<td>Chen</td>
# 		<td>22</td>
# 	</tr>
# </table>
# ```
#
# This will yield the following:
#
# ```
# Lesley		Cordero		24
# Helen		Chen		22
# ```
# - `<li>` initializes the beginning of a list. `<ul>` and `<ol>` each define whether it's an unordered list or an ordered list.

# %% [markdown]
# ### BeautifulSoup
#
# BeautifulSoup is used to parse the data.

# %%
import requests
from bs4 import BeautifulSoup

wiki = "https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States"
page = requests.get(wiki)
html = page.content

soup = BeautifulSoup(html)
# Out:
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %% [markdown]
# Now, let's explore this webpage!

# %% [markdown]
# This outputs the title of the wikipedia page:

# %%
print(soup.title)
# Out:
# <title>List of states and territories of the United States - Wikipedia</title>

# %% [markdown]
# The string version of this can be obtained with:

# %%
print(soup.title.string)
# Out:
# List of states and territories of the United States - Wikipedia

# %% [markdown]
# With `soup.a`, we can output the links under the `<a>` tag. We get the following:

# %%
print(soup.a)
# Out:
# <a id="top"></a>

# %% [markdown]
# But this only allows us to have one output. If we want to extract all the links within `<a>`, we will use `find_all()`, as the following:

# %%
all_links = soup.find_all("a")
for i in all_links:
	print(i.get("href"))
# Out:
# None
# /wiki/Wikipedia:Featured_lists
# #mw-head
# #p-search
# /wiki/List_of_sovereign_states_and_dependent_territories_in_the_Americas
# /wiki/File:Map_of_USA_with_state_names_2.svg
# /wiki/File:Map_of_USA_with_state_names_2.svg
# /wiki/United_States_of_America
# /wiki/Federal_republic
# #cite_note-1
# /wiki/U.S._state
# /wiki/Commonwealth_(U.S._state)
# #cite_note-2
# #cite_note-3
# #cite_note-4
# #cite_note-5
# /wiki/Capital_districts_and_territories#United_States
# /wiki/Seat_of_government
# /wiki/Washington,_D.C.
# /wiki/Territories_of_the_United_States
# /wiki/United_States_Minor_Outlying_Islands
# #cite_note-6
# #cite_note-7
# /wiki/Contiguous_United_States
# /wiki/North_America
# /wiki/Canada
# /wiki/Mexico
# /wiki/Alaska
# /wiki/Hawaii
# /wiki/Archipelago
# /wiki/Pacific_Ocean
# /wiki/Caribbean_Sea
# /wiki/Administrative_division
# /wiki/United_States_Constitution
# /wiki/Elections_in_the_United_States
# /wiki/Local_government_in_the_United_States
# /wiki/Constitutional_amendment#United_States
# /wiki/State_constitution_(United_States)
# /wiki/Republicanism_in_the_United_States
# /wiki/Governor_(United_States)
# /wiki/State_legislature_(United_States)
# /wiki/State_court_(United_States)
# #cite_note-8
# /wiki/United_States_Congress
# /wiki/Bicameral
# /wiki/United_States_Senate
# /wiki/United_States_House_of_Representatives
# /wiki/United_States_congressional_apportionment
# /wiki/United_States_Constitution
# /wiki/United_States_Census
# #cite_note-9
# /wiki/Electoral_College_(United_States)
# /wiki/President_of_the_United_States
# #cite_note-10
# /wiki/Article_Four_of_the_United_States_Constitution
# /wiki/Admission_to_the_Union
# /wiki/Thirteen_Colonies
# /wiki/Equal_footing
# #cite_note-11
# /wiki/Article_One_of_the_United_States_Constitution
# /wiki/Enumerated_powers
# /wiki/District_of_Columbia_Home_Rule_Act
# /wiki/Mayor_of_the_District_of_Columbia
# /wiki/Council_of_the_District_of_Columbia
# #cite_note-12
# /wiki/District_of_Columbia_voting_rights
# /wiki/Non-voting_members_of_the_United_States_House_of_representatives
# #cite_note-13
# /wiki/Twenty-third_Amendment_to_the_United_States_Constitution
# /wiki/Sovereignty
# /wiki/Territories_of_the_United_States
# /wiki/American_Samoa
# /wiki/Guam
# /wiki/Northern_Mariana_Islands
# /wiki/Puerto_Rico
# /wiki/U.S._Virgin_Islands
# /wiki/United_States_Minor_Outlying_Islands
# /wiki/Navassa_Island
# /wiki/Caribbean
# /wiki/Pacific_Ocean
# /wiki/Haiti
# #cite_note-HaitiNavassa-14
# /wiki/Palmyra_Atoll
# /wiki/Territories_of_the_United_States#Incorporated_and_unincorporated_territories
# /wiki/Unincorporated_territories_of_the_United_States
# /wiki/Unorganized_territory#United_States_territory
# /wiki/Organic_Act
# /wiki/Territories_of_the_United_States
# /wiki/California
# /wiki/Wyoming
# /wiki/Vermont
# /wiki/Rhode_Island
# /wiki/Delaware
# /wiki/2010_United_States_Census
# /wiki/Sovereignty
# /wiki/Northern_Mariana_Islands
# #cite_note-CNMI1986-15
# #States
# #Federal_district
# #Territories
# #Inhabited_territories
# #Uninhabited_territories
# #Disputed_territories
# #See_also
# #Notes
# #References
# #External_links
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit&section=1
# /wiki/U.S._state
# /wiki/Admission_to_the_Union
# /wiki/United_States_House_of_Representatives
# /wiki/U.S._Senators
# /wiki/List_of_U.S._state_abbreviations
# #cite_note-16
# #cite_note-b-17
# #cite_note-2010_Census_of_Population_and_Housing-18
# /wiki/List_of_United_States_congressional_districts
# /wiki/Capital_city
# #cite_note-a-19
# #cite_note-State_and_Local_Government_Finances_and_Employment-20
# #cite_note-PopEstUS-21
# /wiki/Alabama
# /wiki/Montgomery,_Alabama
# /wiki/Birmingham,_Alabama
# /wiki/Alaska
# /wiki/Juneau,_Alaska
# /wiki/Anchorage,_Alaska
# /wiki/Arizona
# /wiki/Phoenix,_Arizona
# /wiki/Arkansas
# /wiki/Little_Rock,_Arkansas
# /wiki/California
# /wiki/Sacramento,_California
# /wiki/Los_Angeles
# /wiki/Colorado
# /wiki/Denver
# /wiki/Connecticut
# /wiki/Hartford,_Connecticut
# /wiki/Bridgeport,_Connecticut
# /wiki/Delaware
# /wiki/Dover,_Delaware
# /wiki/Wilmington,_Delaware
# /wiki/Florida
# /wiki/Tallahassee,_Florida
# /wiki/Jacksonville,_Florida
# /wiki/Georgia_(U.S._state)
# /wiki/Atlanta
# /wiki/Hawaii
# /wiki/Honolulu
# /wiki/Idaho
# /wiki/Boise,_Idaho
# /wiki/Illinois
# /wiki/Springfield,_Illinois
# /wiki/Chicago
# /wiki/Indiana
# /wiki/Indianapolis
# /wiki/Iowa
# /wiki/Des_Moines,_Iowa
# /wiki/Kansas
# /wiki/Topeka,_Kansas
# /wiki/Wichita,_Kansas
# /wiki/Kentucky
# #cite_note-22
# /wiki/Frankfort,_Kentucky
# /wiki/Louisville,_Kentucky
# /wiki/Louisiana
# /wiki/Baton_Rouge,_Louisiana
# /wiki/New_Orleans
# /wiki/Maine
# /wiki/Augusta,_Maine
# /wiki/Portland,_Maine
# /wiki/Maryland
# /wiki/Annapolis,_Maryland
# /wiki/Baltimore
# /wiki/Massachusetts
# #cite_note-23
# /wiki/Boston
# /wiki/Michigan
# /wiki/Lansing,_Michigan
# /wiki/Detroit
# /wiki/Minnesota
# /wiki/Saint_Paul,_Minnesota
# /wiki/Minneapolis
# /wiki/Mississippi
# /wiki/Jackson,_Mississippi
# /wiki/Missouri
# /wiki/Jefferson_City,_Missouri
# /wiki/Kansas_City,_Missouri
# /wiki/Montana
# /wiki/Helena,_Montana
# /wiki/Billings,_Montana
# /wiki/Nebraska
# /wiki/Lincoln,_Nebraska
# /wiki/Omaha,_Nebraska
# /wiki/Nevada
# /wiki/Carson_City,_Nevada
# /wiki/Las_Vegas
# /wiki/New_Hampshire
# /wiki/Concord,_New_Hampshire
# /wiki/Manchester,_New_Hampshire
# /wiki/New_Jersey
# /wiki/Trenton,_New_Jersey
# /wiki/Newark,_New_Jersey
# /wiki/New_Mexico
# /wiki/Santa_Fe,_New_Mexico
# /wiki/Albuquerque,_New_Mexico
# /wiki/New_York_(state)
# /wiki/Albany,_New_York
# /wiki/New_York_City
# /wiki/North_Carolina
# /wiki/Raleigh,_North_Carolina
# /wiki/Charlotte,_North_Carolina
# /wiki/North_Dakota
# /wiki/Bismarck,_North_Dakota
# /wiki/Fargo,_North_Dakota
# /wiki/Ohio
# /wiki/Columbus,_Ohio
# /wiki/Oklahoma
# /wiki/Oklahoma_City
# /wiki/Oregon
# /wiki/Salem,_Oregon
# /wiki/Portland,_Oregon
# /wiki/Pennsylvania
# #cite_note-24
# /wiki/Harrisburg,_Pennsylvania
# /wiki/Philadelphia
# /wiki/Rhode_Island
# #cite_note-25
# /wiki/Providence,_Rhode_Island
# /wiki/South_Carolina
# /wiki/Columbia,_South_Carolina
# /wiki/South_Dakota
# /wiki/Pierre,_South_Dakota
# /wiki/Sioux_Falls,_South_Dakota
# /wiki/Tennessee
# /wiki/Nashville,_Tennessee
# /wiki/Memphis,_Tennessee
# /wiki/Texas
# /wiki/Austin,_Texas
# /wiki/Houston
# /wiki/Utah
# /wiki/Salt_Lake_City
# /wiki/Vermont
# /wiki/Montpelier,_Vermont
# /wiki/Burlington,_Vermont
# /wiki/Virginia
# #cite_note-26
# /wiki/Richmond,_Virginia
# /wiki/Virginia_Beach,_Virginia
# /wiki/Washington_(state)
# /wiki/Olympia,_Washington
# /wiki/Seattle
# /wiki/West_Virginia
# /wiki/Charleston,_West_Virginia
# /wiki/Wisconsin
# /wiki/Madison,_Wisconsin
# /wiki/Milwaukee
# /wiki/Wyoming
# /wiki/Cheyenne,_Wyoming
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit&section=2
# /wiki/List_of_U.S._state_abbreviations
# #cite_note-PopEstUS-21
# #cite_note-b-17
# #cite_note-2010_Census_of_Population_and_Housing-18
# /wiki/List_of_United_States_congressional_districts
# /wiki/Washington,_D.C.
# #cite_note-i-27
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit&section=3
# /wiki/File:US_insular_areas_C.png
# /wiki/File:US_insular_areas_C.png
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit&section=4
# /wiki/List_of_U.S._state_abbreviations
# /wiki/Capital_city
# #cite_note-Acquisition_Process_of_Insular_Areas-28
# /wiki/2010_United_States_Census
# #cite_note-b-17
# #cite_note-2010_Census_of_Population_and_Housing_p._1-29
# /wiki/List_of_United_States_congressional_districts
# /wiki/American_Samoa
# /wiki/Pago_Pago
# #cite_note-American_Samoa-30
# #cite_note-i-27
# /wiki/Guam
# /wiki/Hag%C3%A5t%C3%B1a,_Guam
# #cite_note-Guam-31
# #cite_note-i-27
# /wiki/Northern_Mariana_Islands
# #cite_note-32
# /wiki/Saipan
# #cite_note-Northern_Mariana_Islands-33
# #cite_note-CNMI1986-15
# #cite_note-i-27
# /wiki/Puerto_Rico
# #cite_note-34
# /wiki/San_Juan,_Puerto_Rico
# #cite_note-Puerto_Rico-35
# #cite_note-rescomm-36
# /wiki/United_States_Virgin_Islands
# /wiki/Charlotte_Amalie,_United_States_Virgin_Islands
# #cite_note-Virgin_Islands-37
# #cite_note-USVI1917-38
# #cite_note-i-27
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit&section=5
# #cite_note-Acquisition_Process_of_Insular_Areas-28
# #cite_note-11025:_Nationality-39
# #cite_note-40
# /wiki/Baker_Island
# #cite_note-Baker_Island-41
# /wiki/Howland_Island
# #cite_note-Baker_Island-41
# /wiki/Jarvis_Island
# #cite_note-Jarvis_Island-42
# /wiki/Johnston_Atoll
# #cite_note-Johnston_Island-43
# /wiki/Kingman_Reef
# #cite_note-Kingman_Reef_National_Wildlife_Refuge-44
# /wiki/Midway_Atoll
# #cite_note-46
# #cite_note-Midway_Atoll-47
# /wiki/Navassa_Island
# #cite_note-48
# #cite_note-Navassa_Island-49
# /wiki/Palmyra_Atoll
# #cite_note-50
# #cite_note-Palmyra_Atoll-51
# /wiki/Wake_Island
# #cite_note-53
# #cite_note-Wake_Island-52
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit&section=6
# /wiki/List_of_territorial_disputes#Central_America_and_the_Caribbean
# #cite_note-Acquisition_Process_of_Insular_Areas-28
# #cite_note-Lewis.2C_M-54
# #cite_note-Lewis.2C_M-54
# #cite_note-Lewis.2C_M-54
# #cite_note-Lewis.2C_M-54
# /wiki/Bajo_Nuevo_Bank
# #cite_note-Acquisition_Process_of_Insular_Areas-28
# #cite_note-55
# #cite_note-56
# /wiki/Colombia
# /wiki/Jamaica
# /wiki/Nicaragua
# /wiki/Serranilla_Bank
# #cite_note-Acquisition_Process_of_Insular_Areas-28
# #cite_note-57
# #cite_note-58
# /wiki/Colombia
# /wiki/Honduras
# /wiki/Nicaragua
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit&section=7
# /wiki/File:Terrestrial_globe.svg
# /wiki/Portal:Geography
# /wiki/File:North_America_368x348.png
# /wiki/Portal:North_America
# /wiki/Portal:United_States
# /wiki/Territories_of_the_United_States
# /wiki/List_of_fictional_U.S._states
# /wiki/List_of_regions_of_the_United_States
# /wiki/List_of_U.S._states_and_territories_by_population
# /wiki/Lists_of_U.S._state_topics
# /wiki/List_of_U.S._state_abbreviations
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit&section=8
# #cite_ref-16
# /wiki/United_States_Declaration_of_Independence
# /wiki/Articles_of_Confederation
# #cite_ref-b_17-0
# #cite_ref-b_17-1
# #cite_ref-b_17-2
# #cite_ref-a_19-0
# /wiki/City_proper
# /wiki/Metropolitan_area
# #cite_ref-22
# #cite_ref-23
# #cite_ref-24
# #cite_ref-25
# #cite_ref-26
# #cite_ref-i_27-0
# #cite_ref-i_27-1
# #cite_ref-i_27-2
# #cite_ref-i_27-3
# #cite_ref-i_27-4
# /wiki/Delegate_(United_States_Congress)
# /wiki/United_States_House_of_Representatives
# #cite_ref-32
# #cite_ref-34
# #cite_ref-rescomm_36-0
# /wiki/Resident_Commissioner_of_Puerto_Rico
# /wiki/United_States_House_of_Representatives
# #cite_ref-40
# #cite_ref-46
# /wiki/United_States_Fish_and_Wildlife_Service
# #cite_note-United_States_Pacific_Islands_Wildlife_Refuges-45
# #cite_ref-48
# /wiki/Haiti
# #cite_note-HaitiNavassa-14
# #cite_ref-50
# /wiki/United_States_Fish_and_Wildlife_Service
# #cite_note-United_States_Pacific_Islands_Wildlife_Refuges-45
# #cite_ref-53
# /wiki/United_States_Armed_Forces
# /wiki/Wake_Island_Airfield
# #cite_note-Wake_Island-52
# #cite_ref-56
# #cite_ref-58
# #cite_ref-1
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/978-0-8122-1167-2
# #cite_ref-2
# #cite_ref-3
# #cite_ref-4
# #cite_ref-5
# #cite_ref-6
# http://www.state.gov/j/drl/rls/179780.htm
# #cite_ref-7
# http://www.gao.gov/archive/1998/og98005.pdf
# #cite_ref-8
# http://www.leg.state.mn.us/leg/faq/faqtoc.aspx?subject=1
# /wiki/Minnesota_State_Legislature
# #cite_ref-9
# http://www.census.gov/prod/cen2010/briefs/c2010br-08.pdf
# #cite_ref-10
# http://www.heritage.org/constitution/#!/articles/2/essays/79/presidential-electors
# #cite_ref-11
# http://law.justia.com/constitution/us/article-4/22-doctrine-of-equality-of-states.html
# #cite_ref-12
# https://web.archive.org/web/20111117031522/http://www.dccouncil.washington.dc.us/pages/dc-home-rule
# http://www.dccouncil.washington.dc.us/pages/dc-home-rule
# #cite_ref-13
# https://books.google.com/books?id=x1ai7Vtiiu0C&pg=PA165
# /wiki/Sage_Publications
# /wiki/International_Standard_Book_Number
# /wiki/Special:BookSources/9780872897694
# #cite_ref-HaitiNavassa_14-0
# #cite_ref-HaitiNavassa_14-1
# http://faculty.webster.edu/corbetre/haiti/misctopic/navassa/squabble.htm
# #cite_ref-CNMI1986_15-0
# #cite_ref-CNMI1986_15-1
# http://www.archives.gov/federal-register/codification/proclamations/05564.html
# #cite_ref-2010_Census_of_Population_and_Housing_18-0
# #cite_ref-2010_Census_of_Population_and_Housing_18-1
# http://www.census.gov/prod/cen2010/cph-2-1.pdf
# /wiki/United_States_Census_Bureau
# #cite_ref-State_and_Local_Government_Finances_and_Employment_20-0
# http://www.census.gov/compendia/statab/2012/tables/12s0448.pdf
# /wiki/United_States_Census_Bureau
# #cite_ref-PopEstUS_21-0
# #cite_ref-PopEstUS_21-1
# https://www2.census.gov/programs-surveys/popest/tables/2010-2016/state/totals/nst-est2016-01.xlsx
# /wiki/Microsoft_Excel
# /wiki/United_States_Census_Bureau
# #cite_ref-Acquisition_Process_of_Insular_Areas_28-0
# #cite_ref-Acquisition_Process_of_Insular_Areas_28-1

# /wiki/Office_of_Insular_Affairs
# http://www.doi.gov/oia/Islandpages/palmyrapage.htm
# #cite_ref-Wake_Island_52-0
# #cite_ref-Wake_Island_52-1
# https://www.cia.gov/library/publications/the-world-factbook/geos/wq.html
# /wiki/The_World_Factbook
# #cite_ref-Lewis.2C_M_54-0
# #cite_ref-Lewis.2C_M_54-1
# #cite_ref-Lewis.2C_M_54-2
# #cite_ref-Lewis.2C_M_54-3
# http://www.rnw.nl/international-justice/article/when-island-not-island-caribbean-maritime-disputes
# #cite_ref-55
# http://www.geocaching.com/geocache/GC2757B_us-minor-outlying-islands-bajo-nuevo-bank?guid=4a263fd5-14aa-491b-bc21-f866034aa85a
# #cite_ref-57
# http://sanandresislas.es.tl/SERRANILLA.htm
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit&section=9
# https://web.archive.org/web/20120925044541/http://www.doi.gov/oia/islands/politicatypes.cfm
# /wiki/Office_of_Insular_Affairs
# http://www.doi.gov/oia/islands/politicatypes.cfm
# http://kids.clerk.house.gov/high-school/lesson.html?intID=36
# /wiki/Office_of_the_Clerk_of_the_House_of_Representatives
# http://www.census.gov/geo/reference/pdfs/guidestloc/All_GSLCG.pdf
# /wiki/United_States_Census_Bureau
# http://www.irs.gov/pub/irs-utl/zip_code_and_state_abbreviations.pdf
# /wiki/Internal_Revenue_Service
# http://www.gao.gov/archive/1998/og98005.pdf
# /wiki/Government_Accountability_Office
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit&section=10
# https://commons.wikimedia.org/wiki/Category:Subdivisions_of_the_United_States
# http://ucblibraries.colorado.edu/govpubs/st/allstate.htm
# http://www.loc.gov/rr/program/bib/states/
# http://www.usa.gov/Agencies/State_and_Territories.shtml
# http://www.bea.gov/newsreleases/regional/gdp_state/gsp_newsrelease.htm
# /wiki/Template:United_States_political_divisions
# /wiki/Template_talk:United_States_political_divisions
# //en.wikipedia.org/w/index.php?title=Template:United_States_political_divisions&action=edit
# /wiki/United_States
# /wiki/Political_divisions_of_the_United_States
# /wiki/United_States
# /wiki/U.S._state
# /wiki/Alabama
# /wiki/Alaska
# /wiki/Arizona
# /wiki/Arkansas
# /wiki/California
# /wiki/Colorado
# /wiki/Connecticut
# /wiki/Delaware
# /wiki/Florida
# /wiki/Georgia_(U.S._state)
# /wiki/Hawaii
# /wiki/Idaho
# /wiki/Illinois
# /wiki/Indiana
# /wiki/Iowa
# /wiki/Kansas
# /wiki/Kentucky
# /wiki/Louisiana
# /wiki/Maine
# /wiki/Maryland
# /wiki/Massachusetts
# /wiki/Michigan
# /wiki/Minnesota
# /wiki/Mississippi
# /wiki/Missouri
# /wiki/Montana
# /wiki/Nebraska
# /wiki/Nevada
# /wiki/New_Hampshire
# /wiki/New_Jersey
# /wiki/New_Mexico
# /wiki/New_York_(state)
# /wiki/North_Carolina
# /wiki/North_Dakota
# /wiki/Ohio
# /wiki/Oklahoma
# /wiki/Oregon
# /wiki/Pennsylvania
# /wiki/Rhode_Island
# /wiki/South_Carolina
# /wiki/South_Dakota
# /wiki/Tennessee
# /wiki/Texas
# /wiki/Utah
# /wiki/Vermont
# /wiki/Virginia
# /wiki/Washington_(state)
# /wiki/West_Virginia
# /wiki/Wisconsin
# /wiki/Wyoming
# /wiki/Federal_district
# /wiki/Washington,_D.C.
# /wiki/Insular_area
# /wiki/American_Samoa
# /wiki/Guam
# /wiki/Northern_Mariana_Islands
# /wiki/Puerto_Rico
# /wiki/United_States_Virgin_Islands
# /wiki/United_States_Minor_Outlying_Islands
# /wiki/Baker_Island
# /wiki/Howland_Island
# /wiki/Jarvis_Island
# /wiki/Johnston_Atoll
# /wiki/Kingman_Reef
# /wiki/Midway_Atoll
# /wiki/Navassa_Island
# /wiki/Palmyra_Atoll
# /wiki/Wake_Island
# /wiki/Indian_reservation
# /wiki/List_of_Indian_reservations_in_the_United_States
# /wiki/List_of_largest_Indian_reservations_in_the_United_States
# /wiki/Associated_state
# /wiki/Federated_States_of_Micronesia
# /wiki/Marshall_Islands
# /wiki/Palau
# /wiki/Template:USStateLists
# /wiki/Template_talk:USStateLists
# //en.wikipedia.org/w/index.php?title=Template:USStateLists&action=edit
# /wiki/Lists_of_U.S._state_topics
# None
# /wiki/List_of_U.S._states_by_educational_attainment
# /wiki/Irreligion_in_the_United_States#Demographics
# /wiki/List_of_U.S._states%27_largest_cities_by_population
# /wiki/List_of_most_popular_given_names_by_state_in_the_United_States
# /wiki/List_of_the_most_populous_counties_by_U.S._state
# /wiki/List_of_U.S._states_and_territories_by_population
# /wiki/List_of_U.S._states_by_population_density
# /wiki/List_of_U.S._states_by_population_growth_rate
# /wiki/List_of_U.S._states_and_territories_by_birth_and_death_rates
# /wiki/List_of_U.S._states_by_historical_population
# /wiki/List_of_U.S._states_by_African-American_population
# /wiki/List_of_U.S._states_by_Amish_population
# /wiki/List_of_U.S._states_by_Hispanic_and_Latino_population
# /wiki/Spanish_language_in_the_United_States#Geographic_distribution
# /wiki/List_of_U.S._states_by_the_number_of_billionaires
# /wiki/List_of_U.S._state_budgets
# /wiki/List_of_companies_of_the_United_States_by_state
# /wiki/Federal_tax_revenue_by_state
# /wiki/Federal_taxation_and_spending_by_state
# /wiki/List_of_U.S._states_by_GDP
# /wiki/List_of_U.S._states_by_economic_growth_rate
# /wiki/List_of_U.S._states_by_GDP_per_capita
# /wiki/List_of_U.S._states_by_income
# /wiki/List_of_U.S._states_by_income#States_ranked_by_median_household_income
# /wiki/List_of_U.S._states_by_income#States_ranked_by_per_capita_income
# /wiki/List_of_U.S._states_by_Gini_coefficient
# /wiki/Minimum_wage_in_the_United_States
# /wiki/List_of_U.S._states_by_poverty_rate
# /wiki/Sales_taxes_in_the_United_States#By_jurisdiction
# /wiki/List_of_U.S._states_by_sovereign_wealth_funds
# /wiki/State_tax_levels_in_the_United_States
# /wiki/State_income_tax#States_with_flat_rate_individual_income_tax
# /wiki/State_income_tax#States_with_no_individual_income_tax
# /wiki/List_of_U.S._states_by_unemployment_rate
# /wiki/Union_affiliation_by_U.S._state
# /wiki/List_of_U.S._states_by_vehicles_per_capita
# /wiki/List_of_U.S._states_by_carbon_dioxide_emissions
# /wiki/Lists_of_state_parks_by_U.S._state
# /wiki/List_of_U.S._states_by_electricity_production_from_renewable_sources
# /wiki/List_of_Superfund_sites
# /wiki/List_of_U.S._state_and_tribal_wilderness_areas
# /wiki/List_of_U.S._states_and_territories_by_area
# /wiki/List_of_U.S._states_by_coastline
# /wiki/List_of_U.S._states_by_elevation
# /wiki/Geographic_centers_of_the_United_States
# /wiki/State_attorney_general
# /wiki/List_of_capitals_in_the_United_States
# /wiki/List_of_capitals_in_the_United_States#Historical_state_capitals
# /wiki/List_of_state_capitols_in_the_United_States
# /wiki/Comparison_of_U.S._state_governments
# /wiki/List_of_counties_by_U.S._state
# /wiki/Index_of_U.S._counties
# /wiki/List_of_current_U.S._state_legislators
# /wiki/List_of_current_United_States_governors
# /wiki/List_of_current_United_States_lieutenant_governors
# /wiki/List_of_United_States_state_legislatures
# /wiki/List_of_U.S._state_libraries_and_archives
# /wiki/Languages_of_the_United_States#Official_language_status
# /wiki/List_of_U.S._states%27_Poets_Laureate
# /wiki/State_auditor
# /wiki/Secretary_of_state_(U.S._state_government)
# /wiki/Superintendent_(education)#Current_chief_state_school_officers
# /wiki/State_supreme_court
# /wiki/State_treasurer
# /wiki/List_of_U.S._states_by_American_Human_Development_Index
# /wiki/List_of_U.S._states_and_territories_by_fertility_rate
# /wiki/Lists_of_hospitals_in_the_United_States
# /wiki/List_of_U.S._states_by_life_expectancy
# /wiki/Obesity_in_the_United_States#Prevalence_by_state
# /wiki/List_of_U.S._states_by_date_of_admission_to_the_Union
# /wiki/List_of_state_name_etymologies_of_the_United_States
# /wiki/List_of_U.S._state_historical_societies_and_museums
# /wiki/List_of_U.S._National_Historic_Landmarks_by_state
# /wiki/United_States_National_Register_of_Historic_Places_listings
# /wiki/List_of_U.S._state_partition_proposals
# /wiki/Historic_regions_of_the_United_States
# /wiki/Abortion_in_the_United_States_by_state#State_table
# /wiki/Ages_of_consent_in_the_United_States
# /wiki/Alcohol_laws_of_the_United_States
# /wiki/List_of_dry_communities_by_U.S._state
# /wiki/List_of_U.S._states_by_Alford_plea_usage
# /wiki/Restrictions_on_cell_phone_use_while_driving_in_the_United_States
# /wiki/List_of_U.S._state_constitutions
# /wiki/Gun_laws_in_the_United_States_by_state
# /wiki/Gun_violence_in_the_United_States_by_state
# /wiki/List_of_United_States_state_and_local_law_enforcement_agencies
# /wiki/Legality_of_cannabis_by_U.S._state
# /wiki/United_States_Peace_Index
# /wiki/List_of_United_States_state_prisons
# /wiki/List_of_U.S._states_by_incarceration_rate
# /wiki/List_of_U.S._state_laws_on_same-sex_unions
# /wiki/List_of_U.S._state_constitutional_amendments_banning_same-sex_unions_by_type
# /wiki/Same-sex_marriage_law_in_the_United_States_by_state
# /wiki/Seat_belt_legislation_in_the_United_States#The_laws_by_state
# /wiki/List_of_U.S._state_constitutional_provisions_allowing_self-representation_in_state_courts
# /wiki/List_of_smoking_bans_in_the_United_States
# /wiki/List_of_U.S._state_statutory_codes
# /wiki/List_of_U.S._state_abbreviations
# /wiki/List_of_demonyms_for_U.S._states
# /wiki/List_of_fictional_U.S._states
# /wiki/Flags_of_the_U.S._states_and_territories
# /wiki/List_of_U.S._state,_district,_and_territorial_insignia
# /wiki/Lists_of_United_States_state_symbols
# /wiki/List_of_tallest_buildings_by_U.S._state
# /wiki/List_of_time_offsets_by_U.S._state
# /wiki/Departments_of_El_Salvador
# /wiki/Parishes_of_Grenada
# /wiki/Departments_of_Guatemala
# /wiki/Departments_of_Haiti
# /wiki/Departments_of_Honduras
# /wiki/Parishes_of_Jamaica
# /wiki/Administrative_divisions_of_Mexico
# /wiki/Departments_of_Nicaragua
# /wiki/Provinces_of_Panama
# /wiki/Parishes_of_Saint_Kitts_and_Nevis
# /wiki/Quarters_of_Saint_Lucia
# /wiki/Parishes_of_Saint_Vincent_and_the_Grenadines
# /wiki/Regional_corporations_and_municipalities_of_Trinidad_and_Tobago
# /wiki/U.S._state
# /wiki/Table_of_administrative_divisions_by_country
# https://en.wikipedia.org/w/index.php?title=List_of_states_and_territories_of_the_United_States&oldid=782476169
# /wiki/Help:Category
# /wiki/Category:Lists_of_country_subdivisions
# /wiki/Category:States_of_the_United_States
# /wiki/Category:Lists_of_subdivisions_of_the_United_States
# /wiki/Category:United_States_geography-related_lists
# /wiki/Category:Lists_of_states_of_the_United_States
# /wiki/Category:CS1_maint:_Unfit_url
# /wiki/Category:Use_mdy_dates_from_November_2013
# /wiki/Category:Featured_lists
# /wiki/Category:Commons_category_with_local_link_different_than_on_Wikidata
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=List+of+states+and+territories+of+the+United+States
# /w/index.php?title=Special:UserLogin&returnto=List+of+states+and+territories+of+the+United+States
# /wiki/List_of_states_and_territories_of_the_United_States
# /wiki/Talk:List_of_states_and_territories_of_the_United_States
# #
# /wiki/List_of_states_and_territories_of_the_United_States
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=edit
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=history
# #
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Portal:Contents
# /wiki/Portal:Featured_content
# /wiki/Portal:Current_events
# /wiki/Special:Random
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# //shop.wikimedia.org
# /wiki/Help:Contents
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Special:WhatLinksHere/List_of_states_and_territories_of_the_United_States
# /wiki/Special:RecentChangesLinked/List_of_states_and_territories_of_the_United_States
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&oldid=782476169
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&action=info
# https://www.wikidata.org/wiki/Q1682357
# /w/index.php?title=Special:CiteThisPage&page=List_of_states_and_territories_of_the_United_States&id=782476169
# /w/index.php?title=Special:Book&bookcmd=book_creator&referer=List+of+states+and+territories+of+the+United+States
# /w/index.php?title=Special:Book&bookcmd=render_article&arttitle=List+of+states+and+territories+of+the+United+States&returnto=List+of+states+and+territories+of+the+United+States&oldid=782476169&writer=rdf2latex
# /w/index.php?title=List_of_states_and_territories_of_the_United_States&printable=yes
# https://commons.wikimedia.org/wiki/Category:States_of_the_United_States
# https://ar.wikipedia.org/wiki/%D9%82%D8%A7%D8%A6%D9%85%D8%A9_%D8%A7%D9%84%D9%88%D9%84%D8%A7%D9%8A%D8%A7%D8%AA_%D9%88%D8%A7%D9%84%D9%85%D9%86%D8%A7%D8%B7%D9%82_%D8%A7%D9%84%D8%A3%D9%85%D8%B1%D9%8A%D9%83%D9%8A%D8%A9
# https://as.wikipedia.org/wiki/%E0%A6%86%E0%A6%AE%E0%A7%87%E0%A7%B0%E0%A6%BF%E0%A6%95%E0%A6%BE_%E0%A6%AF%E0%A7%81%E0%A6%95%E0%A7%8D%E0%A6%A4%E0%A7%B0%E0%A6%BE%E0%A6%B7%E0%A7%8D%E0%A6%9F%E0%A7%8D%E0%A7%B0%E0%A7%B0_%E0%A7%B0%E0%A6%BE%E0%A6%9C%E0%A7%8D%E0%A6%AF%E0%A6%B8%E0%A6%AE%E0%A7%82%E0%A6%B9
# https://bn.wikipedia.org/wiki/%E0%A6%AE%E0%A6%BE%E0%A6%B0%E0%A7%8D%E0%A6%95%E0%A6%BF%E0%A6%A8_%E0%A6%AF%E0%A7%81%E0%A6%95%E0%A7%8D%E0%A6%A4%E0%A6%B0%E0%A6%BE%E0%A6%B7%E0%A7%8D%E0%A6%9F%E0%A7%8D%E0%A6%B0%E0%A7%87%E0%A6%B0_%E0%A6%B0%E0%A6%BE%E0%A6%9C%E0%A7%8D%E0%A6%AF_%E0%A6%93_%E0%A6%85%E0%A6%9E%E0%A7%8D%E0%A6%9A%E0%A6%B2%E0%A6%B8%E0%A6%AE%E0%A7%82%E0%A6%B9%E0%A7%87%E0%A6%B0_%E0%A6%A4%E0%A6%BE%E0%A6%B2%E0%A6%BF%E0%A6%95%E0%A6%BE
# https://be.wikipedia.org/wiki/%D0%A1%D0%BF%D1%96%D1%81_%D1%88%D1%82%D0%B0%D1%82%D0%B0%D1%9E_%D1%96_%D1%82%D1%8D%D1%80%D1%8B%D1%82%D0%BE%D1%80%D1%8B%D0%B9_%D0%97%D0%A8%D0%90
# https://bar.wikipedia.org/wiki/Listn_vo_de_Bundesstootn
# https://bs.wikipedia.org/wiki/Savezne_dr%C5%BEave_Sjedinjenih_Ameri%C4%8Dkih_Dr%C5%BEava
# https://de.wikipedia.org/wiki/Liste_der_Bundesstaaten_der_Vereinigten_Staaten
# https://es.wikipedia.org/wiki/Anexo:Estados_y_Territorios_de_los_Estados_Unidos
# https://fa.wikipedia.org/wiki/%D8%A7%DB%8C%D8%A7%D9%84%D8%AA%E2%80%8C%D9%87%D8%A7%DB%8C_%D8
org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://wikimediafoundation.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://wikimediafoundation.org/wiki/Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=List_of_states_and_territories_of_the_United_States&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# //www.mediawiki.org/

# %% [markdown]
# Since we're looking for the capital of each state, let's use `find_all` to retrieve the table tags:

# %%
all_tables = soup.find_all('table')

# %% [markdown]
# Now we have to identify the right table. We filter this by figuring out what the attribute class name is. In chrome, you can check the class name by right click on the table of web page. Then you click "Inspect" and copy the class name. You also go through the output of above command find the class name of right table.

# %%
right_table = soup.find('table', class_='wikitable sortable plainrowheaders')

# %% [markdown]
# We're now going to store the data from the website. We'll grab the first few columns, so we'll initialize a list for each of these here:

# %%
A = []
B = []
C = []

# %% [markdown]
# Next, is to actually grab the needed data and add it to each list. We iterate through the scraped data, row by row:

# %%
for row in right_table.findAll("tr"):
    cells = row.findAll('td')
    states = row.findAll('th') 
    if len(cells) == 9 or len(cells) == 8: 
        A.append(cells[0].find(text=True))
        B.append(states[0].find(text=True))
        C.append(cells[1].find(text=True))

# %% [markdown]
# Here, we actually create the DataFrame with pandas:

# %%
import pandas as pd
df = pd.DataFrame(A, columns=['Number'])
df['State/UT'] = B
df['Admin_Capital'] = C

# %% [markdown]
# ### rvest
#
# Now we'll try scraping a website with R. R has a library called `rvest` which allows you scrape the HTML from any webpage. In the following two lines, we call this library and take the HTML with the `read_html` function.

# %%
library(rvest)
movie <- read_html("http://www.imdb.com/title/tt1490017/")
# Out:
# Loading required package: xml2

# %% [markdown]
# Let's now scape some information from the website. `html_nodes` easily extract pieces out of HTML documents using css selectors while `html_text` extracts attributes, text, and tag name from the HTML. Using these two functions, we can extract the rating for this movie.

# %%
rating <- movie %>%
    html_nodes("strong span") %>%
    html_text() %>%
    as.numeric()
print(rating)
# Out:
# [1] 7.8

# %% [markdown]
# Next, let's get the cast of the movie:

# %%
cast <- movie %>%
    html_nodes("#titleCast .itemprop span") %>%
    html_text()
print(cast)
# Out:
#  [1] "Will Arnett"     "Elizabeth Banks" "Craig Berry"     "Alison Brie"
#  [5] "David Burrows"   "Anthony Daniels" "Charlie Day"     "Amanda Farinos"
#  [9] "Keith Ferguson"  "Will Ferrell"    "Will Forte"      "Dave Franco"
# [13] "Morgan Freeman"  "Todd Hansen"     "Jonah Hill"

# %% [markdown]
# And lastly, we extract the first movie review on the site:

# %%
review <- movie %>%
    html_nodes("#titleUserReviewsTeaser p") %>%
    html_text()
print(review)
# Out:
# [1] "This film has great animation and a great story, it has an all star voice cast example Morgan freeman and will Ferrell. This film will be up on the shelve as one of the greatest films ever animated, ever thought about and ever written. When I was a kid playing with Lego I never thought to my self that they will make a film on it now that they have all my Christmases have come at once. Cant wait for the special features on blue ray. This movie will be up there with toy story 1 2 and 3 , the lion king , frozen and wreck it Ralph. The power of good films are in Lego hands people are genius congrats to all the Oscars for the road ahead"

# %% [markdown]
# ## Advanced Web Scraping
#
#
# ### Sitemaps
#
# The Sitemaps protocol allows a webmaster to inform search engines about URLs on a website that are available for crawling. A Sitemap is an XML file that lists the URLs for a site. It allows webmasters to include additional information about each URL: when it was last updated, how often it changes, and how important it is in relation to other URLs in the site. This allows search engines to crawl the site more intelligently. Sitemaps are a URL inclusion protocol and complement robots.txt, a URL exclusion protocol.
#
# An example of what a sample XML sitemap might look like is:
#
# ```
# <?xml version="1.0" encoding="UTF-8"?>
#
# <urlset xmlns="http://www.sitemaps.org/schemas/sitemap/0.9">
#
#    <url>
#
#       <loc>http://www.example.com/</loc>
#
#       <lastmod>2005-01-01</lastmod>
#
#       <changefreq>monthly</changefreq>
#
#       <priority>0.8</priority>
#
#    </url>
#
# </urlset>
# ```
#
# ### Estimating Website Size
#
# The size of the website will affect how you crawl it. If the website is just a few hundred URLs, such as our example website, efficiency is not important. However, if the website has over a million web pages, downloading each sequentially would take months.

# %% [markdown]
# ### Regular Expressions
#
# A regular expression is a sequence of characters that define a string.
#
# #### Simplest Form
#
# The simplest form of a regular expression is a sequence of characters contained within <b>two backslashes</b>. For example, <i>python</i> would be
#
# ```
# \python
# ```
#
# #### Case Sensitivity
#
# Regular Expressions are <b>case sensitive</b>, which means
#
# ```
# \p and \P
# ```
# are distinguishable from eachother. This means <i>python</i> and <i>Python</i> would have to be represented differently, as follows:
#
# ```
# \python and \Python
# ```
#
# We can check these are different by running:

# %%
import re
re1 = re.compile('python')
print(bool(re1.match('Python')))
# Out:
# False

# %% [markdown]
# #### Disjunctions
#
# If you want a regular expression to represent both <i>python</i> and <i>Python</i>, however, you can use <b>brackets</b> or the <b>pipe</b> symbol as the disjunction of the two forms. For example,
# ```
# [Pp]ython or \Python|python
# ```
# could represent either <i>python</i> or <i>Python</i>. Likewise,
#
# ```
# [0123456789]
# ```
# would represent a single integer digit. The pipe symbols are typically used for interchangable strings, such as in the following example:
#
# ```
# \dog|cat
# ```

# %% [markdown]
# #### Ranges
#
# If we want a regular expression to express the disjunction of a range of characters, we can use a <b>dash</b>. For example, instead of the previous example, we can write
#
# ```
# [0-9]
# ```
# Similarly, we can represent all characters of the alphabet with
#
# ```
# [a-z]
# ```
#
# #### Exclusions
#
# Brackets can also be used to represent what an expression <b>cannot</b> be if you combine it with the <b>caret</b> sign. For example, the expression
#
# ```
# [^p]
# ```
# represents any character, special characters included, but p.

# %% [markdown]
# #### Question Marks
#
# Question marks can be used to represent the expressions containing zero or one instances of the previous character. For example,
#
# ```
# <i>\colou?r
# ```
# represents either <i>color</i> or <i>colour</i>. Question marks are often used in cases of plurality. For example,
#
# ```
# <i>\computers?
# ```
# can be either <i>computers</i> or <i>computer</i>. If you want to extend this to more than one character, you can put the simple sequence within parenthesis, like this:
#
# ```
# \Feb(ruary)?
# ```
# This would evaluate to either <i>February</i> or <i>Feb</i>.

# %% [markdown]
# #### Kleene Star
#
# To represent the expressions containing zero or <b>more</b> instances of the previous character, we use an <b>asterisk</b> as the kleene star. To represent the set of strings containing <i>a, ab, abb, abbb, ...</i>, the following regular expression would be used:
# ```
# \ab*
# ```
#
# #### Wildcards
#
# Wildcards are used to represent the possibility of any character and symbolized with a <b>period</b>. For example,
#
# ```
# \beg.n
# ```
# From this regular expression, the strings <i>begun, begin, began,</i> etc., can be generated.
#
# #### Kleene+
#
# To represent the expressions containing at <b>least</b> one or more instances of the previous character, we use a <b>plus</b> sign. To represent the set of strings containing <i>ab, abb, abbb, ...</i>, the following regular expression would be used:
#
# ```
# \ab+
# ```

# %% [markdown]
# ### REs & BeautifulSoup
#
# If the previous section on regular expressions seemed a little disjointed, hereâ€™s where it all ties together. BeautifulSoup and regular expressions go hand in hand when it comes to scraping the Web. In fact, most functions that take in a string argument will also take in a regular expression as well.
#
# Looking at [this](http://www.pythonscraping.com/pages/page3.html) webpage, we'll see that there are product images of the following form:
#
# ``` HTML
# <img src="../img/gifts/img3.jpg">
# ```
# If we wanted to grab URLs to all of the product images, it might seem fairly straightforward: just grab all the image tags using `.findAll("img")`. Unfortunately, thereâ€™s a problem. There are â€œextraâ€ images (i.e, logos), often have hidden images, and blank images used for spacing and aligning elements, and other random image tags you might not be aware of.
#
# The solution is to look for another approach. In this case, we can look at the file path of the product images. You've seen this part before:

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
html = urlopen("http://www.pythonscraping.com/pages/page3.html")
bsObj = BeautifulSoup(html)
# Out:
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/local/Cellar/python3/3.6.1/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %% [markdown]
# This prints out only the relative image paths that start with ../img/gifts/img and end in `.jpg`:

# %%
images = bsObj.findAll("img", {"src":re.compile("\.\.\/img\/gifts/img.*\.jpg")})
for image in images:
    print(image["src"])
# Out:
# ../img/gifts/img1.jpg
# ../img/gifts/img2.jpg
# ../img/gifts/img3.jpg
# ../img/gifts/img4.jpg
# ../img/gifts/img6.jpg

# %% [markdown]
# A regular expression can be inserted as any argument in a BeautifulSoup expression, allowing you a great deal of flexibility in finding target elements.

# %% [markdown]
# ### Lambda Expressions
#
# Recall, a lambda expression is a function that is passed into another function as a variable. Instead of defining a function as f(x, y), you may define a function as f(g(x), y), or even f(g(x), h(x)).
#
# BeautifulSoup allows us to pass certain types of functions as parameters into the findAll function. The only restriction is that these functions must take a tag object as an argument and return a boolean. Every tag object that BeautifulSoup encounters is evaluated in this function, and tags that evaluate to â€œtrueâ€ are returned while the rest are discarded.
#
# For example, the following retrieves all tags that have exactly two attributes:

# %%
bsObj.findAll(lambda tag: len(tag.attrs) == 2)
# Out:
# [<img src="../img/gifts/logo.jpg" style="float:left;"/>,
#  <tr class="gift" id="gift1"><td>
#  Vegetable Basket
#  </td><td>
#  This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#  <span class="excitingNote">Now with super-colorful bell peppers!</span>
#  </td><td>
#  $15.00
#  </td><td>
#  <img src="../img/gifts/img1.jpg"/>
#  </td></tr>,
#  <tr class="gift" id="gift2"><td>
#  Russian Nesting Dolls
#  </td><td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td><td>
#  $10,000.52
#  </td><td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td></tr>,
#  <tr class="gift" id="gift3"><td>
#  Fish Painting
#  </td><td>
#  If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
#  </td><td>
#  $10,005.00
#  </td><td>
#  <img src="../img/gifts/img3.jpg"/>
#  </td></tr>,
#  <tr class="gift" id="gift4"><td>
#  Dead Parrot
#  </td><td>
#  This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
#  </td><td>
#  $0.50
#  </td><td>
#  <img src="../img/gifts/img4.jpg"/>
#  </td></tr>,
#  <tr class="gift" id="gift5"><td>
#  Mystery Box
#  </td><td>
#  If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
#  </td><td>
#  $1.50
#  </td><td>
#  <img src="../img/gifts/img6.jpg"/>
#  </td></tr>]

# %% [markdown]
# Using lambda functions in BeautifulSoup, selectors can act as a great substitute for writing a regular expression, if youâ€™re comfortable with writing a little code.
